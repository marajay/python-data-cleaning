# %%
import pandas as pd

# %%
movies = pd.read_csv('assignment.csv')

# %%
movies
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
#data cleaning methods
# change all columns to lower case
# remove the unnamed 0 column
# the release year to be consistent
# the country column needs to be consistent
# the content rating needs to be consistent
# drop the unnamed 8 columns 
# remove the dollar sign in the income column so to make numerical calculations on it
# score column needs to be consistent

# %%
movies.shape
# Out:
# (101, 13)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      101 non-null    int64
#  1   IMBD title ID   100 non-null    object
#  2   Original titlÊ  100 non-null    object
#  3   Release year    100 non-null    object
#  4   Genrë¨          100 non-null    object
#  5   Duration        99 non-null     object
#  6   Country         100 non-null    object
#  7   Content Rating  77 non-null     object
#  8   Director        100 non-null    object
#  9   Unnamed: 8      0 non-null      float64
#  10  Income          100 non-null    object
#  11   Votes          100 non-null    object
#  12  Score           100 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.4+ KB

# %%
movies.describe()
# Out:
#        Unnamed: 0  Unnamed: 8
# count  101.000000         0.0
# mean    50.000000         NaN
# std     29.300171         NaN
# min      0.000000         NaN
# 25%     25.000000         NaN
# 50%     50.000000         NaN
# 75%     75.000000         NaN
# max    100.000000         NaN

# %%
movies.columns= movies.columns.str.lower()

# %%
movies
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %%
movies.drop(movies.columns[[0, 9, 12]], axis=1, inplace=True)

# %%
movies
# Out:
#     imbd title id               original titlê  release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
movies.rename(columns={'imbd title id': 'title_id','original titlê': 'original_title','content rating':'content_rating','release year': 'release_year','genrë¨': 'genre'}, inplace=True)
# Renamed some column for easy navigation

# %%
movies
# Out:
#       title_id               original_title  release_year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    09 21 1972
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content_rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
movies.release_year
# Out:
# 0        1995-02-10
# 1        09 21 1972
# 2       23 -07-2008
# 3        1975-09-25
# 4        1994-10-28
#            ...
# 96       1974-03-21
# 97       1982-03-18
# 98       1965-12-20
# 99       2011-10-21
# 100      1953-02-05
# Name: release_year, Length: 101, dtype: object

# %%
movies['release_year'] =movies['release_year'].replace(['09 21 1972','23 -07-2008','22 Feb 04','10-29-99','23rd December of 1966 ',' 01/16-03', '18/11/1976','21-11-46','The 6th of marzo, year 1951',],['1972-09-21','2008-07-23','2004-02-22','1999-10-29','1966-12-23','2003-01-16','1976-11-18','1946-11-21','1951-03-06'])

# %%
movies.release_year
# Out:
# 0        1995-02-10
# 1        1972-09-21
# 2       23 -07-2008
# 3        1975-09-25
# 4        1994-10-28
#            ...
# 96       1974-03-21
# 97       1982-03-18
# 98       1965-12-20
# 99       2011-10-21
# 100      1953-02-05
# Name: release_year, Length: 101, dtype: object

# %%
movies.genre
# Out:
# 0                           Drama
# 1                    Crime, Drama
# 2            Action, Crime, Drama
# 3                    Crime, Drama
# 4                    Crime, Drama
#                   ...
# 96           Comedy, Crime, Drama
# 97     Adventure, Drama, Thriller
# 98                        Western
# 99                          Drama
# 100      Comedy, Musical, Romance
# Name: genre, Length: 101, dtype: object

# %%
movies['genre'].str.split(',', expand = True)
# Out:
#              0         1          2
# 0        Drama      None       None
# 1        Crime     Drama       None
# 2       Action     Crime      Drama
# 3        Crime     Drama       None
# 4        Crime     Drama       None
# ..         ...       ...        ...
# 96      Comedy     Crime      Drama
# 97   Adventure     Drama   Thriller
# 98     Western      None       None
# 99       Drama      None       None
# 100     Comedy   Musical    Romance
#
# [101 rows x 3 columns]

# %%
movies['first_genre']=movies['genre'].str.split(',',expand=True)[0]

# %%
movies
# Out:
#       title_id               original_title  release_year  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10
# 1    tt0068646                The Godfather    1972-09-21
# 2    tt0468569              The Dark Knight   23 -07-2008
# 3    tt0071562       The Godfather: Part II    1975-09-25
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...
# 96   tt0070735                    The Sting    1974-03-21
# 97   tt0082096                     Das Boot    1982-03-18
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content_rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
movies.drop(movies.columns[[3]], axis=1, inplace=True)

# %%
movies
# Out:
#       title_id               original_title  release_year duration  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10      142
# 1    tt0068646                The Godfather    1972-09-21      175
# 2    tt0468569              The Dark Knight   23 -07-2008      152
# 3    tt0071562       The Godfather: Part II    1975-09-25      220
# 4    tt0110912                 Pulp Fiction    1994-10-28
# ..         ...                          ...           ...      ...
# 96   tt0070735                    The Sting    1974-03-21      129
# 97   tt0082096                     Das Boot    1982-03-18      149
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20      132
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21      123
# 100  tt0045152          Singin' in the Rain    1953-02-05      103
#
#           country content_rating              director         income  \
# 0             USA              R        Frank Darabont     $ 28815245
# ...

# %%
movies['country'] = movies['country'].replace(['US','New Zesland','New Zeland','Italy1','US.','West Germany'],['USA',' New Zealand',' New Zealand','Italy','USA','Germany'])

# %%
movies.country
# Out:
# 0          USA
# 1          USA
# 2          USA
# 3          USA
# 4          USA
#         ...
# 96         USA
# 97     Germany
# 98       Italy
# 99        Iran
# 100        USA
# Name: country, Length: 101, dtype: object

# %%
movies.content_rating
# Out:
# 0          R
# 1          R
# 2      PG-13
# 3          R
# 4          R
#        ...
# 96        PG
# 97         R
# 98       NaN
# 99     PG-13
# 100      NaN
# Name: content_rating, Length: 101, dtype: object

# %%
movies['content_rating'] = movies['content_rating'].replace(['Approved','unrated','G','PG','R'],['Rated','Not Rated','PG-13','PG-13','Rated'])

# %%
movies.content_rating
# Out:
# 0      Rated
# 1      Rated
# 2      PG-13
# 3      Rated
# 4      Rated
#        ...
# 96     PG-13
# 97     Rated
# 98       NaN
# 99     PG-13
# 100      NaN
# Name: content_rating, Length: 101, dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title_id        100 non-null    object
#  1   original_title  100 non-null    object
#  2   release_year    100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8    votes          100 non-null    object
#  9   first_genre     100 non-null    object
# dtypes: object(10)
# memory usage: 8.0+ KB

# %%
movies.duration
# Out:
# 0      142
# 1      175
# 2      152
# 3      220
# 4
#       ...
# 96     129
# 97     149
# 98     132
# 99     123
# 100    103
# Name: duration, Length: 101, dtype: object

# %%
movies['duration'] = movies['duration'].replace(['Nan', 'Not Applicable', '-','Inf','178c','NaN'], [0, 0, 0,0,0,0])

# %%
movies.income
# Out:
# 0         $ 28815245
# 1        $ 246120974
# 2       $ 1005455211
# 3      $ 4o8,035,783
# 4        $ 222831817
#            ...
# 96       $ 156000000
# 97        $ 11487676
# 98        $ 15000000
# 99        $ 22926076
# 100        $ 1864182
# Name: income, Length: 101, dtype: object

# %%
movies['income'].str.split('$',expand=True)
# Out:
#     0              1
# 0           28815245
# 1          246120974
# 2         1005455211
# 3        4o8,035,783
# 4          222831817
# ..  ..           ...
# 96         156000000
# 97          11487676
# 98          15000000
# 99          22926076
# 100          1864182
#
# [101 rows x 2 columns]

# %%
movies['income'] = movies['income'].str.split('$', expand = True)[1]

# %%
movies.head(50)
# Out:
#      title_id                                     original_title  \
# 0   tt0111161                           The Shawshank Redemption
# 1   tt0068646                                      The Godfather
# 2   tt0468569                                    The Dark Knight
# 3   tt0071562                             The Godfather: Part II
# 4   tt0110912                                       Pulp Fiction
# 5   tt0167260      The Lord of the Rings: The Return of the King
# 6   tt0108052                                   Schindler's List
# 7   tt0050083                                       12 Angry Men
# 8   tt1375666                                          Inception
# 9   tt0137523                                         Fight Club
# 10  tt0109830                                       Forrest Gump
# 11  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12  tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
movies = movies.drop(index=13)

# %%
movies
# Out:
#       title_id               original_title  release_year duration  country  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10      142      USA
# 1    tt0068646                The Godfather    1972-09-21      175      USA
# 2    tt0468569              The Dark Knight   23 -07-2008      152      USA
# 3    tt0071562       The Godfather: Part II    1975-09-25      220      USA
# 4    tt0110912                 Pulp Fiction    1994-10-28               USA
# ..         ...                          ...           ...      ...      ...
# 96   tt0070735                    The Sting    1974-03-21      129      USA
# 97   tt0082096                     Das Boot    1982-03-18      149  Germany
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20      132    Italy
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21      123     Iran
# 100  tt0045152          Singin' in the Rain    1953-02-05      103      USA
#
# ...

# %%
movies. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title_id        100 non-null    object
#  1   original_title  100 non-null    object
#  2   release_year    100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8    votes          100 non-null    object
#  9   first_genre     100 non-null    object
# dtypes: object(10)
# memory usage: 8.6+ KB

# %%
movies['income'] = movies['income'].astype(int)

# %%
movies.to_csv('cleaned_data.csv')
